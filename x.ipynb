# %%
from datasets import load_dataset

# %%
df_metaData_raw_cellPhones = load_dataset(
    "McAuley-Lab/Amazon-Reviews-2023",
    "raw_meta_Cell_Phones_and_Accessories",
    split="full",
    trust_remote_code=True,
)

df_metaData_raw_cellPhones = df_metaData_raw_cellPhones.to_pandas()

# %%
df_metaData_raw_cellPhones.columns
# Out:
# Index(['main_category', 'title', 'average_rating', 'rating_number', 'features',
#        'description', 'price', 'images', 'videos', 'store', 'categories',
#        'details', 'parent_asin', 'bought_together', 'subtitle', 'author'],
#       dtype='object')

# %%
df_metaData_raw_cellPhones['main_category'].unique()
# Out:
# array(['Cell Phones & Accessories', 'Sports & Outdoors',
#        'All Electronics', 'AMAZON FASHION', 'Computers', 'Amazon Home',
#        'Industrial & Scientific', 'Office Products', 'Camera & Photo',
#        'Portable Audio & Accessories', None, 'Home Audio & Theater',
#        'Fire Phone', 'Books', 'Automotive', 'Musical Instruments',
#        'Video Games', 'Tools & Home Improvement',
#        'Health & Personal Care', 'Amazon Devices', 'Baby',
#        'Arts, Crafts & Sewing', 'Grocery', 'All Beauty', 'Apple Products',
#        'Pet Supplies', 'Toys & Games', 'Entertainment', 'Movies & TV',
#        'GPS & Navigation', 'Car Electronics', 'Handmade',
#        'Collectible Coins', 'Software', 'Appliances', 'Digital Music',
#        'Amazon Fire TV', 'Collectibles & Fine Art', 'Audible Audiobooks',
#        'Buy a Kindle', 'Sports Collectibles'], dtype=object)

# %%
df_metaData_raw_cellPhones['bought_together'].unique()
# Out:
# array([None], dtype=object)

# %%
df_metaData_raw_Beauty = load_dataset(
    "McAuley-Lab/Amazon-Reviews-2023",
    "raw_meta_All_Beauty",
    split="full",
    trust_remote_code=True,
)

df_metaData_raw_Beauty = df_metaData_raw_Beauty.to_pandas()

# %%
df_metaData_raw_Beauty.columns
# Out:
# Index(['main_category', 'title', 'average_rating', 'rating_number', 'features',
#        'description', 'price', 'images', 'videos', 'store', 'categories',
#        'details', 'parent_asin', 'bought_together', 'subtitle', 'author'],
#       dtype='object')

# %%
df_metaData_raw_Beauty['main_category'].unique()
# Out:
# array(['All Beauty', 'Premium Beauty'], dtype=object)

# %%
df_metaData_raw_Beauty['bought_together'].unique()
# Out:
# array([None], dtype=object)
